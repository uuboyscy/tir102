# %%
import pandas as pd
from pandasql import sqldf

# %%
file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"
file_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"

df_staff = pd.read_csv(file_path_staff)
df_staff_detail = pd.read_csv(file_path_staff_detail)

# %%
sql = """
    select * from df_staff
"""

sqldf(sql)
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
sql = """
select *
from df_staff_detail sd
left join df_staff s
on sd.ID = s.ID
"""

sqldf(sql)
# Out:
#     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
# 0    1     A  2019-08-09   1   Mike       2   45      M   60000
# 1    1     S  2020-12-08   1   Mike       2   45      M   60000
# 2    2     A  2021-05-30   2   Judy       2   30      F   48000
# 3    3     A  2018-03-26   3  Allen       1   22      M   50000
# 4    3     S  2020-12-08   3  Allen       1   22      M   50000
# 5    4     A  2022-05-02   4    Tom       2   47      M   47000
# 6    5     A  2019-11-05   5   Jack       3   36      M   52000
# 7    5     S  2022-04-25   5   Jack       3   36      M   52000
# 8    6     A  2022-03-03   6   Abby       2   24      F   45000
# 9    7     A  2017-03-29   7  Trump       1   80      M   80000
# 10   7     S  2018-05-02   7  Trump       1   80      M   80000
# 11   7     M  2021-09-01   7  Trump       1   80      M   80000
# 12   8     A  2018-11-26   8  Marry       3   29      F   87000
# 13   8     S  2020-03-15   8  Marry       3   29      F   87000
# 14   8     M  2022-05-03   8  Marry       3   29      F   87000

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'import pandas as pd\nfrom pandasql import sqldf',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'sql = """\n    select * from df_staff\n"""\n\nsqldf(sql)',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#   'globals()'],
#  '_oh': {4:    ID   Name  DeptId  Age Gender  Salary
#   0   1   Mike       2   45      M   60000
#   1   2   Judy       2   30      F   48000
#   2   3  Allen       1   22      M   50000
#   3   4    Tom       2   47      M   47000
#   4   5   Jack       3   36      M   52000
#   5   6   Abby       2   24      F   45000
#   6   7  Trump       1   80      M   80000
#   7   8  Marry       3   29      F   87000,
#   6:     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#   0    1     A  2019-08-09   1   Mike       2   45      M   60000
#   1    1     S  2020-12-08   1   Mike       2   45      M   60000
#   2    2     A  2021-05-30   2   Judy       2   30      F   48000
#   3    3     A  2018-03-26   3  Allen       1   22      M   50000
#   4    3     S  2020-12-08   3  Allen       1   22      M   50000
#   5    4     A  2022-05-02   4    Tom       2   47      M   47000
#   6    5     A  2019-11-05   5   Jack       3   36      M   52000
#   7    5     S  2022-04-25   5   Jack       3   36      M   52000
#   8    6     A  2022-03-03   6   Abby       2   24      F   45000
#   9    7     A  2017-03-29   7  Trump       1   80      M   80000
#   10   7     S  2018-05-02   7  Trump       1   80      M   80000
#   11   7     M  2021-09-01   7  Trump       1   80      M   80000
#   12   8     A  2018-11-26   8  Marry       3   29      F   87000
#   13   8     S  2020-03-15   8  Marry       3   29      F   87000
#   14   8     M  2022-05-03   8  Marry       3   29      F   87000},
#  '_dh': [PosixPath('/workspaces/tir102/data-pipeline/src/pandas_practice')],
#  'In': ['',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'import pandas as pd\nfrom pandasql import sqldf',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'sql = """\n    select * from df_staff\n"""\n\nsqldf(sql)',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#   'globals()'],
#  'Out': {4:    ID   Name  DeptId  Age Gender  Salary
#   0   1   Mike       2   45      M   60000
#   1   2   Judy       2   30      F   48000
#   2   3  Allen       1   22      M   50000
#   3   4    Tom       2   47      M   47000
#   4   5   Jack       3   36      M   52000
#   5   6   Abby       2   24      F   45000
#   6   7  Trump       1   80      M   80000
#   7   8  Marry       3   29      F   87000,
#   6:     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#   0    1     A  2019-08-09   1   Mike       2   45      M   60000
#   1    1     S  2020-12-08   1   Mike       2   45      M   60000
#   2    2     A  2021-05-30   2   Judy       2   30      F   48000
#   3    3     A  2018-03-26   3  Allen       1   22      M   50000
#   4    3     S  2020-12-08   3  Allen       1   22      M   50000
#   5    4     A  2022-05-02   4    Tom       2   47      M   47000
#   6    5     A  2019-11-05   5   Jack       3   36      M   52000
#   7    5     S  2022-04-25   5   Jack       3   36      M   52000
#   8    6     A  2022-03-03   6   Abby       2   24      F   45000
#   9    7     A  2017-03-29   7  Trump       1   80      M   80000
#   10   7     S  2018-05-02   7  Trump       1   80      M   80000
#   11   7     M  2021-09-01   7  Trump       1   80      M   80000
#   12   8     A  2018-11-26   8  Marry       3   29      F   87000
#   13   8     S  2020-03-15   8  Marry       3   29      F   87000
#   14   8     M  2022-05-03   8  Marry       3   29      F   87000},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0xffff88798440>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0xffff91515430>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0xffff91515430>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_':     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#  0    1     A  2019-08-09   1   Mike       2   45      M   60000
#  1    1     S  2020-12-08   1   Mike       2   45      M   60000
#  2    2     A  2021-05-30   2   Judy       2   30      F   48000
#  3    3     A  2018-03-26   3  Allen       1   22      M   50000
#  4    3     S  2020-12-08   3  Allen       1   22      M   50000
#  5    4     A  2022-05-02   4    Tom       2   47      M   47000
#  6    5     A  2019-11-05   5   Jack       3   36      M   52000
#  7    5     S  2022-04-25   5   Jack       3   36      M   52000
#  8    6     A  2022-03-03   6   Abby       2   24      F   45000
#  9    7     A  2017-03-29   7  Trump       1   80      M   80000
#  10   7     S  2018-05-02   7  Trump       1   80      M   80000
#  11   7     M  2021-09-01   7  Trump       1   80      M   80000
#  12   8     A  2018-11-26   8  Marry       3   29      F   87000
#  13   8     S  2020-03-15   8  Marry       3   29      F   87000
#  14   8     M  2022-05-03   8  Marry       3   29      F   87000,
#  '__':    ID   Name  DeptId  Age Gender  Salary
#  0   1   Mike       2   45      M   60000
#  1   2   Judy       2   30      F   48000
#  2   3  Allen       1   22      M   50000
#  3   4    Tom       2   47      M   47000
#  4   5   Jack       3   36      M   52000
#  5   6   Abby       2   24      F   45000
#  6   7  Trump       1   80      M   80000
#  7   8  Marry       3   29      F   87000,
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/tir102/data-pipeline/src/pandas_practice/p_11_pandas_sql.ipynb',
#  '_i': 'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#  '_ii': 'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""',
#  '_iii': 'sql = """\n    select * from df_staff\n"""\n\nsqldf(sql)',
#  '_i1': 'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#  'file_path_staff': '/workspaces/tir102/data-pipeline/resource/staff.csv',
#  'file_path_staff_detail': '/workspaces/tir102/data-pipeline/resource/staff_detail.csv',
#  '_i2': 'import pandas as pd\nfrom pandasql import sqldf',
#  'pd': <module 'pandas' from '/usr/local/lib/python3.12/site-packages/pandas/__init__.py'>,
#  'sqldf': <function pandasql.sqldf.sqldf(query, env=None, db_uri='sqlite:///:memory:')>,
#  '_i3': 'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#  'df_staff':    ID   Name  DeptId  Age Gender  Salary
#  0   1   Mike       2   45      M   60000
#  1   2   Judy       2   30      F   48000
#  2   3  Allen       1   22      M   50000
#  3   4    Tom       2   47      M   47000
#  4   5   Jack       3   36      M   52000
#  5   6   Abby       2   24      F   45000
#  6   7  Trump       1   80      M   80000
#  7   8  Marry       3   29      F   87000,
#  'df_staff_detail':     ID Level  UpdateDate
#  0    1     A  2019-08-09
#  1    1     S  2020-12-08
#  2    2     A  2021-05-30
#  3    3     A  2018-03-26
#  4    3     S  2020-12-08
#  5    4     A  2022-05-02
#  6    5     A  2019-11-05
#  7    5     S  2022-04-25
#  8    6     A  2022-03-03
#  9    7     A  2017-03-29
#  10   7     S  2018-05-02
#  11   7     M  2021-09-01
#  12   8     A  2018-11-26
#  13   8     S  2020-03-15
#  14   8     M  2022-05-03,
#  '_i4': 'sql = """\n    select * from df_staff\n"""\n\nsqldf(sql)',
#  'sql': '\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n',
#  '_4':    ID   Name  DeptId  Age Gender  Salary
#  0   1   Mike       2   45      M   60000
#  1   2   Judy       2   30      F   48000
#  2   3  Allen       1   22      M   50000
#  3   4    Tom       2   47      M   47000
#  4   5   Jack       3   36      M   52000
#  5   6   Abby       2   24      F   45000
#  6   7  Trump       1   80      M   80000
#  7   8  Marry       3   29      F   87000,
#  '_i5': 'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""',
#  '_i6': 'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#  '_6':     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#  0    1     A  2019-08-09   1   Mike       2   45      M   60000
#  1    1     S  2020-12-08   1   Mike       2   45      M   60000
#  2    2     A  2021-05-30   2   Judy       2   30      F   48000
#  3    3     A  2018-03-26   3  Allen       1   22      M   50000
#  4    3     S  2020-12-08   3  Allen       1   22      M   50000
#  5    4     A  2022-05-02   4    Tom       2   47      M   47000
#  6    5     A  2019-11-05   5   Jack       3   36      M   52000
#  7    5     S  2022-04-25   5   Jack       3   36      M   52000
#  8    6     A  2022-03-03   6   Abby       2   24      F   45000
#  9    7     A  2017-03-29   7  Trump       1   80      M   80000
#  10   7     S  2018-05-02   7  Trump       1   80      M   80000
#  11   7     M  2021-09-01   7  Trump       1   80      M   80000
#  12   8     A  2018-11-26   8  Marry       3   29      F   87000
#  13   8     S  2020-03-15   8  Marry       3   29      F   87000
#  14   8     M  2022-05-03   8  Marry       3   29      F   87000,
#  '_i7': 'globals()'}

# %%
globals()["df_staff_detail"]
# Out:
#     ID Level  UpdateDate
# 0    1     A  2019-08-09
# 1    1     S  2020-12-08
# 2    2     A  2021-05-30
# 3    3     A  2018-03-26
# 4    3     S  2020-12-08
# 5    4     A  2022-05-02
# 6    5     A  2019-11-05
# 7    5     S  2022-04-25
# 8    6     A  2022-03-03
# 9    7     A  2017-03-29
# 10   7     S  2018-05-02
# 11   7     M  2021-09-01
# 12   8     A  2018-11-26
# 13   8     S  2020-03-15
# 14   8     M  2022-05-03

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'import pandas as pd\nfrom pandasql import sqldf',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'sql = """\n    select * from df_staff\n"""\n\nsqldf(sql)',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#   'globals()',
#   'globals()["df_staff_detail"]',
#   'locals()'],
#  '_oh': {4:    ID   Name  DeptId  Age Gender  Salary
#   0   1   Mike       2   45      M   60000
#   1   2   Judy       2   30      F   48000
#   2   3  Allen       1   22      M   50000
#   3   4    Tom       2   47      M   47000
#   4   5   Jack       3   36      M   52000
#   5   6   Abby       2   24      F   45000
#   6   7  Trump       1   80      M   80000
#   7   8  Marry       3   29      F   87000,
#   6:     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#   0    1     A  2019-08-09   1   Mike       2   45      M   60000
#   1    1     S  2020-12-08   1   Mike       2   45      M   60000
#   2    2     A  2021-05-30   2   Judy       2   30      F   48000
#   3    3     A  2018-03-26   3  Allen       1   22      M   50000
#   4    3     S  2020-12-08   3  Allen       1   22      M   50000
#   5    4     A  2022-05-02   4    Tom       2   47      M   47000
#   6    5     A  2019-11-05   5   Jack       3   36      M   52000
#   7    5     S  2022-04-25   5   Jack       3   36      M   52000
#   8    6     A  2022-03-03   6   Abby       2   24      F   45000
#   9    7     A  2017-03-29   7  Trump       1   80      M   80000
#   10   7     S  2018-05-02   7  Trump       1   80      M   80000
#   11   7     M  2021-09-01   7  Trump       1   80      M   80000
#   12   8     A  2018-11-26   8  Marry       3   29      F   87000
#   13   8     S  2020-03-15   8  Marry       3   29      F   87000
#   14   8     M  2022-05-03   8  Marry       3   29      F   87000,
#   7: {...},
#   8:     ID Level  UpdateDate
#   0    1     A  2019-08-09
#   1    1     S  2020-12-08
#   2    2     A  2021-05-30
#   3    3     A  2018-03-26
#   4    3     S  2020-12-08
#   5    4     A  2022-05-02
#   6    5     A  2019-11-05
#   7    5     S  2022-04-25
#   8    6     A  2022-03-03
#   9    7     A  2017-03-29
#   10   7     S  2018-05-02
#   11   7     M  2021-09-01
#   12   8     A  2018-11-26
#   13   8     S  2020-03-15
#   14   8     M  2022-05-03},
#  '_dh': [PosixPath('/workspaces/tir102/data-pipeline/src/pandas_practice')],
#  'In': ['',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'import pandas as pd\nfrom pandasql import sqldf',
#   'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#   'sql = """\n    select * from df_staff\n"""\n\nsqldf(sql)',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""',
#   'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#   'globals()',
#   'globals()["df_staff_detail"]',
#   'locals()'],
#  'Out': {4:    ID   Name  DeptId  Age Gender  Salary
#   0   1   Mike       2   45      M   60000
#   1   2   Judy       2   30      F   48000
#   2   3  Allen       1   22      M   50000
#   3   4    Tom       2   47      M   47000
#   4   5   Jack       3   36      M   52000
#   5   6   Abby       2   24      F   45000
#   6   7  Trump       1   80      M   80000
#   7   8  Marry       3   29      F   87000,
#   6:     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#   0    1     A  2019-08-09   1   Mike       2   45      M   60000
#   1    1     S  2020-12-08   1   Mike       2   45      M   60000
#   2    2     A  2021-05-30   2   Judy       2   30      F   48000
#   3    3     A  2018-03-26   3  Allen       1   22      M   50000
#   4    3     S  2020-12-08   3  Allen       1   22      M   50000
#   5    4     A  2022-05-02   4    Tom       2   47      M   47000
#   6    5     A  2019-11-05   5   Jack       3   36      M   52000
#   7    5     S  2022-04-25   5   Jack       3   36      M   52000
#   8    6     A  2022-03-03   6   Abby       2   24      F   45000
#   9    7     A  2017-03-29   7  Trump       1   80      M   80000
#   10   7     S  2018-05-02   7  Trump       1   80      M   80000
#   11   7     M  2021-09-01   7  Trump       1   80      M   80000
#   12   8     A  2018-11-26   8  Marry       3   29      F   87000
#   13   8     S  2020-03-15   8  Marry       3   29      F   87000
#   14   8     M  2022-05-03   8  Marry       3   29      F   87000,
#   7: {...},
#   8:     ID Level  UpdateDate
#   0    1     A  2019-08-09
#   1    1     S  2020-12-08
#   2    2     A  2021-05-30
#   3    3     A  2018-03-26
#   4    3     S  2020-12-08
#   5    4     A  2022-05-02
#   6    5     A  2019-11-05
#   7    5     S  2022-04-25
#   8    6     A  2022-03-03
#   9    7     A  2017-03-29
#   10   7     S  2018-05-02
#   11   7     M  2021-09-01
#   12   8     A  2018-11-26
#   13   8     S  2020-03-15
#   14   8     M  2022-05-03},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0xffff88798440>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0xffff91515430>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0xffff91515430>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_':     ID Level  UpdateDate
#  0    1     A  2019-08-09
#  1    1     S  2020-12-08
#  2    2     A  2021-05-30
#  3    3     A  2018-03-26
#  4    3     S  2020-12-08
#  5    4     A  2022-05-02
#  6    5     A  2019-11-05
#  7    5     S  2022-04-25
#  8    6     A  2022-03-03
#  9    7     A  2017-03-29
#  10   7     S  2018-05-02
#  11   7     M  2021-09-01
#  12   8     A  2018-11-26
#  13   8     S  2020-03-15
#  14   8     M  2022-05-03,
#  '__': {...},
#  '___':     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#  0    1     A  2019-08-09   1   Mike       2   45      M   60000
#  1    1     S  2020-12-08   1   Mike       2   45      M   60000
#  2    2     A  2021-05-30   2   Judy       2   30      F   48000
#  3    3     A  2018-03-26   3  Allen       1   22      M   50000
#  4    3     S  2020-12-08   3  Allen       1   22      M   50000
#  5    4     A  2022-05-02   4    Tom       2   47      M   47000
#  6    5     A  2019-11-05   5   Jack       3   36      M   52000
#  7    5     S  2022-04-25   5   Jack       3   36      M   52000
#  8    6     A  2022-03-03   6   Abby       2   24      F   45000
#  9    7     A  2017-03-29   7  Trump       1   80      M   80000
#  10   7     S  2018-05-02   7  Trump       1   80      M   80000
#  11   7     M  2021-09-01   7  Trump       1   80      M   80000
#  12   8     A  2018-11-26   8  Marry       3   29      F   87000
#  13   8     S  2020-03-15   8  Marry       3   29      F   87000
#  14   8     M  2022-05-03   8  Marry       3   29      F   87000,
#  '__vsc_ipynb_file__': '/workspaces/tir102/data-pipeline/src/pandas_practice/p_11_pandas_sql.ipynb',
#  '_i': 'globals()["df_staff_detail"]',
#  '_ii': 'globals()',
#  '_iii': 'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#  '_i1': 'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#  'file_path_staff': '/workspaces/tir102/data-pipeline/resource/staff.csv',
#  'file_path_staff_detail': '/workspaces/tir102/data-pipeline/resource/staff_detail.csv',
#  '_i2': 'import pandas as pd\nfrom pandasql import sqldf',
#  'pd': <module 'pandas' from '/usr/local/lib/python3.12/site-packages/pandas/__init__.py'>,
#  'sqldf': <function pandasql.sqldf.sqldf(query, env=None, db_uri='sqlite:///:memory:')>,
#  '_i3': 'file_path_staff = "/workspaces/tir102/data-pipeline/resource/staff.csv"\nfile_path_staff_detail = "/workspaces/tir102/data-pipeline/resource/staff_detail.csv"\n\ndf_staff = pd.read_csv(file_path_staff)\ndf_staff_detail = pd.read_csv(file_path_staff_detail)',
#  'df_staff':    ID   Name  DeptId  Age Gender  Salary
#  0   1   Mike       2   45      M   60000
#  1   2   Judy       2   30      F   48000
#  2   3  Allen       1   22      M   50000
#  3   4    Tom       2   47      M   47000
#  4   5   Jack       3   36      M   52000
#  5   6   Abby       2   24      F   45000
#  6   7  Trump       1   80      M   80000
#  7   8  Marry       3   29      F   87000,
#  'df_staff_detail':     ID Level  UpdateDate
#  0    1     A  2019-08-09
#  1    1     S  2020-12-08
#  2    2     A  2021-05-30
#  3    3     A  2018-03-26
#  4    3     S  2020-12-08
#  5    4     A  2022-05-02
#  6    5     A  2019-11-05
#  7    5     S  2022-04-25
#  8    6     A  2022-03-03
#  9    7     A  2017-03-29
#  10   7     S  2018-05-02
#  11   7     M  2021-09-01
#  12   8     A  2018-11-26
#  13   8     S  2020-03-15
#  14   8     M  2022-05-03,
#  '_i4': 'sql = """\n    select * from df_staff\n"""\n\nsqldf(sql)',
#  'sql': '\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n',
#  '_4':    ID   Name  DeptId  Age Gender  Salary
#  0   1   Mike       2   45      M   60000
#  1   2   Judy       2   30      F   48000
#  2   3  Allen       1   22      M   50000
#  3   4    Tom       2   47      M   47000
#  4   5   Jack       3   36      M   52000
#  5   6   Abby       2   24      F   45000
#  6   7  Trump       1   80      M   80000
#  7   8  Marry       3   29      F   87000,
#  '_i5': 'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""',
#  '_i6': 'sql = """\nselect *\nfrom df_staff_detail sd\nleft join df_staff s\non sd.ID = s.ID\n"""\n\nsqldf(sql)',
#  '_6':     ID Level  UpdateDate  ID   Name  DeptId  Age Gender  Salary
#  0    1     A  2019-08-09   1   Mike       2   45      M   60000
#  1    1     S  2020-12-08   1   Mike       2   45      M   60000
#  2    2     A  2021-05-30   2   Judy       2   30      F   48000
#  3    3     A  2018-03-26   3  Allen       1   22      M   50000
#  4    3     S  2020-12-08   3  Allen       1   22      M   50000
#  5    4     A  2022-05-02   4    Tom       2   47      M   47000
#  6    5     A  2019-11-05   5   Jack       3   36      M   52000
#  7    5     S  2022-04-25   5   Jack       3   36      M   52000
#  8    6     A  2022-03-03   6   Abby       2   24      F   45000
#  9    7     A  2017-03-29   7  Trump       1   80      M   80000
#  10   7     S  2018-05-02   7  Trump       1   80      M   80000
#  11   7     M  2021-09-01   7  Trump       1   80      M   80000
#  12   8     A  2018-11-26   8  Marry       3   29      F   87000
#  13   8     S  2020-03-15   8  Marry       3   29      F   87000
#  14   8     M  2022-05-03   8  Marry       3   29      F   87000,
#  '_i7': 'globals()',
#  '_7': {...},
#  '_i8': 'globals()["df_staff_detail"]',
#  '_8':     ID Level  UpdateDate
#  0    1     A  2019-08-09
#  1    1     S  2020-12-08
#  2    2     A  2021-05-30
#  3    3     A  2018-03-26
#  4    3     S  2020-12-08
#  5    4     A  2022-05-02
#  6    5     A  2019-11-05
#  7    5     S  2022-04-25
#  8    6     A  2022-03-03
#  9    7     A  2017-03-29
#  10   7     S  2018-05-02
#  11   7     M  2021-09-01
#  12   8     A  2018-11-26
#  13   8     S  2020-03-15
#  14   8     M  2022-05-03,
#  '_i9': 'locals()'}

# %%
df_staff.dtypes
# Out:
# ID         int64
# Name      object
# DeptId     int64
# Age        int64
# Gender    object
# Salary     int64
# dtype: object

# %%
insert_sql = """
insert into df_staff
values (9, 'Test', 4, 50, 'F', 100000)
"""
sqldf(insert_sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# OperationalError: no such table: df_staff
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/pandasql/sqldf.py:61, in PandaSQL.__call__(self, query, env)
#      60 try:
# ---> 61     result = read_sql(query, conn)
#      62 except DatabaseError as ex:
#
# File /usr/local/lib/python3.12/site-packages/pandas/io/sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File /usr/local/lib/python3.12/site-packages/pandas/io/sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1790 """
#    1791 Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835 """
# -> 1836 result = self.execute(sql, params)
#    1837 columns = result.keys()
#
# File /usr/local/lib/python3.12/site-packages/pandas/io/sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) no such table: df_staff
# [SQL:
# insert into df_staff
# values (9, 'Test', 4, 50, 'F', 100000)
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# Cell In[12], line 5
#       1 insert_sql = """
#       2 insert into df_staff
#       3 values (9, 'Test', 4, 50, 'F', 100000)
#       4 """
# ----> 5 sqldf(insert_sql)
#
# File /usr/local/lib/python3.12/site-packages/pandasql/sqldf.py:156, in sqldf(query, env, db_uri)
#     124 def sqldf(query, env=None, db_uri='sqlite:///:memory:'):
#     125     """
#     126     Query pandas data frames using sql syntax
#     127     This function is meant for backward compatibility only. New users are encouraged to use the PandaSQL class.
#    (...)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# File /usr/local/lib/python3.12/site-packages/pandasql/sqldf.py:63, in PandaSQL.__call__(self, query, env)
#      61     result = read_sql(query, conn)
#      62 except DatabaseError as ex:
# ---> 63     raise PandaSQLException(ex)
#      64 except ResourceClosedError:
#      65     # query returns nothing
#      66     result = None
#
# PandaSQLException: (sqlite3.OperationalError) no such table: df_staff
# [SQL:
# insert into df_staff
# values (9, 'Test', 4, 50, 'F', 100000)
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
columns = ["article", "author", "price"]
data = [
    ["0001", "B", 3.99],
    ["0002", "A", 10.99],
    ["0003", "C", 1.69],
    ["0004", "B", 19.95],
    ["0005", "A", 6.96],
]
prticle_price_df = pd.DataFrame(data=data, columns=columns)
prticle_price_df
# Out:
#   article author  price
# 0    0001      B   3.99
# 1    0002      A  10.99
# 2    0003      C   1.69
# 3    0004      B  19.95
# 4    0005      A   6.96

# %%
temp_sql = """
select
    *,
    ROW_NUMBER() OVER (PARTITION BY author ORDER BY price DESC) as ROW_ID
from prticle_price_df
"""

sqldf(temp_sql)
# Out:
#   article author  price  ROW_ID
# 0    0002      A  10.99       1
# 1    0005      A   6.96       2
# 2    0004      B  19.95       1
# 3    0001      B   3.99       2
# 4    0003      C   1.69       1

# %%
sql = """
with tmp_prticle_price_df as (
    select
        *,
        ROW_NUMBER() OVER (PARTITION BY author ORDER BY price DESC) as ROW_ID
    from prticle_price_df
)
select
    article,
    author,
    price
from tmp_prticle_price_df
where ROW_ID = 1
"""
sqldf(
    sql,
)
# Out:
#   article author  price
# 0    0002      A  10.99
# 1    0004      B  19.95
# 2    0003      C   1.69
