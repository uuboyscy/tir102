# %%
import pandas as pd

# %%
file_path = r"/workspaces/tir102/data-pipeline/resource/holding.csv"
# file_path = "C:\\workspaces\\tir102\\data-pipeline\\resource\\holding.csv"

df = pd.read_csv(file_path, nrows=1000000)

# %%
df
# Out:
#          portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0       2998623  2020/11/30              1  2021/01/08         2.55
# 1       2998623  2020/11/30              2  2021/01/08         1.98
# 2       2998623  2020/11/30              3  2021/01/08         1.89
# 3       2998623  2020/11/30              4  2021/01/08         1.75
# 4       2998623  2020/11/30              5  2021/01/08         1.65
# ...         ...         ...            ...         ...          ...
# 999995  3092652  2020/12/31             23  2021/01/08         0.50
# 999996  3092652  2020/12/31             24  2021/01/08         0.50
# 999997  3092652  2020/12/31             25  2021/01/08         0.50
# 999998  3092652  2020/12/31             26  2021/01/08         0.50
# 999999  3092652  2020/12/31             27  2021/01/08         0.50
#
#         nbr_shares    market_val                    security_name     cusip
# ...

# %%
df.head()
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
df.head(15)
# Out:
#      portno   report_dt  security_rank      eff_dt  percent_tna   nbr_shares  \
# 0   2998623  2020/11/30              1  2021/01/08         2.55    7078982.0
# 1   2998623  2020/11/30              2  2021/01/08         1.98    3087680.0
# 2   2998623  2020/11/30              3  2021/01/08         1.89    3714760.0
# 3   2998623  2020/11/30              4  2021/01/08         1.75    2815186.0
# 4   2998623  2020/11/30              5  2021/01/08         1.65    5248941.0
# 5   2998623  2020/11/30              6  2021/01/08         1.64     866386.0
# 6   2998623  2020/11/30              7  2021/01/08         1.63    2194727.0
# 7   2998623  2020/11/30              8  2021/01/08         1.60    5045923.0
# 8   2998623  2020/11/30              9  2021/01/08         1.59    1403360.0
# 9   2998623  2020/11/30             10  2021/01/08         1.54    3065766.0
# 10  2998623  2020/11/30             11  2021/01/08         1.54  186854700.0
# ...

# %%
df.tail(15)
# Out:
#          portno   report_dt  security_rank      eff_dt  percent_tna  \
# 999985  3092652  2020/12/31             13  2021/01/08         0.54
# 999986  3092652  2020/12/31             14  2021/01/08         0.54
# 999987  3092652  2020/12/31             15  2021/01/08         0.53
# 999988  3092652  2020/12/31             15  2021/01/08         0.53
# 999989  3092652  2020/12/31             17  2021/01/08         0.53
# 999990  3092652  2020/12/31             18  2021/01/08         0.53
# 999991  3092652  2020/12/31             19  2021/01/08         0.53
# 999992  3092652  2020/12/31             20  2021/01/08         0.52
# 999993  3092652  2020/12/31             21  2021/01/08         0.51
# 999994  3092652  2020/12/31             22  2021/01/08         0.50
# 999995  3092652  2020/12/31             23  2021/01/08         0.50
# 999996  3092652  2020/12/31             24  2021/01/08         0.50
# 999997  3092652  2020/12/31             25  2021/01/08         0.50
# ...

# %%
df[3:5]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
df.loc[[1, 3, 5]]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
#
#      market_val                    security_name     cusip
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 5  1.997713e+08          GOLDMAN SACHS GROUP INC  38141G10

# %%
df.loc[[1, 3, 5], "report_dt":"eff_dt"]
# Out:
#     report_dt  security_rank      eff_dt
# 1  2020/11/30              2  2021/01/08
# 3  2020/11/30              4  2021/01/08
# 5  2020/11/30              6  2021/01/08

# %%
df.loc[[1, 3, 5], ["report_dt", "eff_dt"]]
# Out:
#     report_dt      eff_dt
# 1  2020/11/30  2021/01/08
# 3  2020/11/30  2021/01/08
# 5  2020/11/30  2021/01/08

# %%
df.loc[5:10, ["report_dt", "eff_dt"]]
# Out:
#      report_dt      eff_dt
# 5   2020/11/30  2021/01/08
# 6   2020/11/30  2021/01/08
# 7   2020/11/30  2021/01/08
# 8   2020/11/30  2021/01/08
# 9   2020/11/30  2021/01/08
# 10  2020/11/30  2021/01/08

# %%
df.iloc[5:10, [2, 4]]
# Out:
#    security_rank  percent_tna
# 5              6         1.64
# 6              7         1.63
# 7              8         1.60
# 8              9         1.59
# 9             10         1.54

# %%
df[["security_rank", "percent_tna"]]
# Out:
#         security_rank  percent_tna
# 0                   1         2.55
# 1                   2         1.98
# 2                   3         1.89
# 3                   4         1.75
# 4                   5         1.65
# ...               ...          ...
# 999995             23         0.50
# 999996             24         0.50
# 999997             25         0.50
# 999998             26         0.50
# 999999             27         0.50
#
# [1000000 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['portno', 'report_dt', 'security_rank', 'eff_dt', 'percent_tna',
#        'nbr_shares', 'market_val', 'security_name', 'cusip'],
#       dtype='object')

# %%
df.dtypes
# Out:
# portno            object
# report_dt         object
# security_rank      int64
# eff_dt            object
# percent_tna      float64
# nbr_shares       float64
# market_val       float64
# security_name     object
# cusip             object
# dtype: object

# %%
df["portno"].unique()
# Out:
# array(['2998623', '2998638', '2998809', ..., '3092616', '3092619',
#        '3092652'], dtype=object)

# %%
len(df["portno"].unique())
# Out:
# 3867

# %%
df["market_val"].mean()
# Out:
# np.float64(8295992.487287326)

# %%
df["market_val"].std()
# Out:
# np.float64(81533843.61393921)

# %%
"""
select
    portno,
    count(portno)
from table
group by portno
"""
df["portno"].value_counts()
# Out:
# portno
# 3076812    10798
# 3062442     9285
# 3092256     8456
# 307883d     8331
# 3062436     7676
#            ...
# 3075153        1
# 307512c        1
# 3073329        1
# 3080052        1
# 3082554        1
# Name: count, Length: 3867, dtype: int64

# %%
df.describe()
# Out:
#         security_rank     percent_tna    nbr_shares    market_val
# count  1000000.000000  1000000.000000  1.000000e+06  1.000000e+06
# mean       878.182552        0.313768  4.992272e+07  8.295992e+06
# std       1319.490208        1.713193  1.176281e+10  8.153384e+07
# min          1.000000     -200.000000 -4.398750e+12 -7.381045e+09
# 25%        116.000000        0.010000  2.069500e+04  1.783209e+05
# 50%        398.000000        0.050000  2.000000e+05  8.666431e+05
# 75%       1090.000000        0.210000  1.208042e+06  3.516512e+06
# max      12388.000000      300.080000  6.667220e+12  1.862818e+10

# %%
"""
select
    portno,
    sum(percent_tna)
from table
group by portno
"""
df.groupby(["portno"]).sum()["percent_tna"]
# Out:
# portno
# 2998623     99.79
# 2998638     99.89
# 2998809     99.50
# 2998821    100.01
# 2999052      0.08
#             ...
# 309260a      0.10
# 309260d    100.79
# 3092616      0.07
# 3092619    100.06
# 3092652    118.57
# Name: percent_tna, Length: 3867, dtype: float64

# %%
df["portno"] == "2998623"
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Name: portno, Length: 1000000, dtype: bool

# %%
df[df["portno"] == "2998623"]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0    2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1    2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2    2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3    2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4    2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
# ..       ...         ...            ...         ...          ...         ...
# 346  2998623  2020/11/30            352  2021/01/08         0.00      1303.0
# 347  2998623  2020/11/30            352  2021/01/08         0.00      3702.0
# 348  2998623  2020/11/30            352  2021/01/08         0.00      5645.0
# 349  2998623  2020/11/30            352  2021/01/08         0.00         1.0
# 350  2998623  2020/11/30            352  2021/01/08         0.00         0.0
#
# ...

# %%
"""
select *
from table
where portno = '2998623'
and percent_tna > 1.8
"""
filter_2998623 = df["portno"] == "2998623"
filter_percent_tna_gt_2 = df["percent_tna"] > 1.8

df[
    filter_2998623 & filter_percent_tna_gt_2
]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644

# %%
"""
select *
from table
where percent_tna > 2
or percent_tna < 1
"""

filter_percent_tna_gt_2 = df["percent_tna"] > 2
filter_percent_tna_lt_1 = df["percent_tna"] < 1

df[
    filter_percent_tna_gt_2 | filter_percent_tna_lt_1
]
# Out:
#          portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0       2998623  2020/11/30              1  2021/01/08         2.55
# 32      2998623  2020/11/30             33  2021/01/08         0.97
# 33      2998623  2020/11/30             34  2021/01/08         0.94
# 34      2998623  2020/11/30             35  2021/01/08         0.94
# 35      2998623  2020/11/30             36  2021/01/08         0.91
# ...         ...         ...            ...         ...          ...
# 999995  3092652  2020/12/31             23  2021/01/08         0.50
# 999996  3092652  2020/12/31             24  2021/01/08         0.50
# 999997  3092652  2020/12/31             25  2021/01/08         0.50
# 999998  3092652  2020/12/31             26  2021/01/08         0.50
# 999999  3092652  2020/12/31             27  2021/01/08         0.50
#
#         nbr_shares    market_val                  security_name     cusip
# 0        7078982.0  3.103426e+08              GENERAL MOTORS CO  37045V10
# ...

# %%
"""
select *
from table
where portno = '2998623'
and (
    percent_tna > 2 or percent_tna < 1
)
"""

df[
    filter_2998623 & (
        filter_percent_tna_gt_2 | filter_percent_tna_lt_1
    )
]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0    2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 32   2998623  2020/11/30             33  2021/01/08         0.97   2350480.0
# 33   2998623  2020/11/30             34  2021/01/08         0.94    724928.0
# 34   2998623  2020/11/30             35  2021/01/08         0.94   3616628.0
# 35   2998623  2020/11/30             36  2021/01/08         0.91   2015089.0
# ..       ...         ...            ...         ...          ...         ...
# 346  2998623  2020/11/30            352  2021/01/08         0.00      1303.0
# 347  2998623  2020/11/30            352  2021/01/08         0.00      3702.0
# 348  2998623  2020/11/30            352  2021/01/08         0.00      5645.0
# 349  2998623  2020/11/30            352  2021/01/08         0.00         1.0
# 350  2998623  2020/11/30            352  2021/01/08         0.00         0.0
#
# ...
